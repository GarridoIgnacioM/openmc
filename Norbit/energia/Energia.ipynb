# %% [markdown]
# # `OpenMC` example

# %% [markdown]
# ### Importing the Python modules necessary to run OpenMC

# %%
import os
os.environ['OPENMC_CROSS_SECTIONS'] = '/home/nacho/openmc/data/endfb-vii.1-hdf5/cross_sections.xml'
import numpy as np
import matplotlib.pyplot as plt
import openmc
import pandas as pd
from matplotlib.colors import LogNorm
from PIL import Image   
from uncertainties import ufloat, unumpy
import h5py

# %% [markdown]
# ### Materials

# %% [markdown]
# Materials are defined by calling [`openmc.Material()`](https://docs.openmc.org/en/stable/pythonapi/generated/openmc.Material.html#openmc-material) to create the material object and then using the `mat.add_nuclide()` or `mat.add_element()` methods to build the composition.
#
# The first parameter is the nuclide or element, the second one is the fraction, and the third one is the units.
#
# Compositions can be expressed in percentage of atoms (`ao`), percentage of mass (`wo`) or atom density (`at/cm3`).
#
# To se the total density of the material, the module `.set_density()` should be called. The possible units are `g/cm3`, `atom/b-cm`, `kg/m3` or `sum` (asumes that the concentrations of the nuclides/elements are in `atom/b-cm`)
#
# It is possible to ad an $S(\alpha,\beta)$ library, which will replace the cross sections for low energies.

# %%
deu = openmc.Material(1, 'deuterio', 293.5943174)
deu.add_nuclide('H2', 1, 'ao')
deu.set_density('atom/cm3', (985796446e13/0.0165)*0.01)
print(deu)



hid = openmc.Material(2, 'hidrogeno', 293.5943174)
hid.add_nuclide('H1', 1, 'ao')
hid.set_density('g/cm3', 0.01)
print(hid)
# Out:
# Material
# 	ID             =	1
# 	Name           =	deuterio
# 	Temperature    =	293.5943174
# 	Density        =	5.974523915151516e+21 [atom/cm3]
# 	Volume         =	None [cm^3]
# 	S(a,b) Tables
# 	Nuclides
# 	H2             =	1            [ao]
#
# Material
# 	ID             =	2
# 	Name           =	hidrogeno
# 	Temperature    =	293.5943174
# 	Density        =	0.01 [g/cm3]
# 	Volume         =	None [cm^3]
# 	S(a,b) Tables
# 	Nuclides
# 	H1             =	1            [ao]
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=2.
#   warn(msg, IDWarning)

# %% [markdown]
# ### Geometry

# %% [markdown]
# The geometry is defined using [Constructive Solid Geometry](https://en.wikipedia.org/wiki/Constructive_solid_geometry) (CSG). First, a set of simple surfaces are defined. Mathematically, the surfaces are defined as $f(x,y,z)=0$, giving the parameters of the function. Each surface defines two regions, one where $f(x,y,z)>0$, and one where $f(x,y,z)<0$. By combining the regions using the union (`|`), intersection (`&`) and complement (`~`) we can define regions of the space.
#
# The basic unit of the geometry in OpenMC is the *Cell*, which is a region of space with something that fills it.
#
# The surfaces with `vacuum` boundary conditions means that the particles that reach this surface will be eliminated. By default, the `transmission` boundary is setted. Other options are `reflective`, `periodic` and `white`.
#
# A collection of cells is a *Universe*, and it can be used to fill other cells for nested geometries.
#
# The surface units are in `cm`

# %% [markdown]
# #### Surfaces

# %%
L=20
xtop=openmc.XPlane(x0=L/2, boundary_type='vacuum', surface_id=1)
xbot=openmc.XPlane(x0=-L/2, boundary_type='vacuum', surface_id=2)
ytop=openmc.YPlane(y0=L/2, boundary_type='vacuum', surface_id=3)
ybot=openmc.YPlane(y0=-L/2, boundary_type='vacuum', surface_id=4)
ztop=openmc.ZPlane(z0=L/2, boundary_type='vacuum', surface_id=5)
zbot=openmc.ZPlane(z0=-L/2, boundary_type='vacuum', surface_id=6)
# Out:
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=1.
#   warn(msg, IDWarning)
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=2.
#   warn(msg, IDWarning)
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=3.
#   warn(msg, IDWarning)
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=4.
#   warn(msg, IDWarning)
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=5.
#   warn(msg, IDWarning)
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=6.
#   warn(msg, IDWarning)

# %% [markdown]
# #### Regions

# %%
region=-xtop & +xbot & -ytop & +ybot & -ztop & +zbot

# %% [markdown]
# #### Cells

# %%
cell=openmc.Cell(region=region,fill=deu,cell_id=1)
# Out:
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)

# %% [markdown]
# #### Universe(s)

# %%
univ01 =openmc.Universe(cells= [cell], universe_id=1)
# Out:
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=1.
#   warn(msg, IDWarning)

# %% [markdown]
# The `Universe()` class has a `plot()` method to show the geometry. L We can plot the geometry using different colors for the different materials or for the different cells

# %%
univ01.plot(width=(40, 40),  basis='xy', color_by='material')
univ01.plot(width=(40, 40), basis='xz', color_by='material')
univ01.plot(width=(40, 40), basis='yz', color_by='material')

# %% [markdown]
# ### Plots (optional)

# %% [markdown]
# It is possible to call a `openmc.plot` run command later. In this case, the `Plot` module should be called and defined

# %%
plots = openmc.Plots()

plot_xz = openmc.Plot()
plot_xz.id = 1
plot_xz.basis = 'xz'
plot_xz.origin = (0,0,0.0)
plot_xz.width = (40,40)
plot_xz.pixels = (100, 100)
plot_xz.color_by='material'
plots.append(plot_xz)
# Out:
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another PlotBase instance already exists with id=1.
#   warn(msg, IDWarning)

# %% [markdown]
# ### mesh

# %%
mesh = openmc.RegularMesh(mesh_id=1)
mesh.lower_left=(-L/2,-L/2,-L/2)
mesh.upper_right=(L/2,L/2,L/2)
mesh.dimension = [1, 1, 1]
# Out:
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another MeshBase instance already exists with id=1.
#   warn(msg, IDWarning)

# %% [markdown]
# ### Tallies (optional)

# %% [markdown]
# With the `Tallies` module, we can define what we want to compute from the simulations. These tallies count a specific *Score* discrimined by different *Filters*.

# %% [markdown]
# #### Filters

# %%
tallies = openmc.Tallies()
current_nomatter = openmc.Tally(name='Fdet')
current_nomatter.scores = ['current']
current_nomatter.filters = [openmc.EnergyFilter([90.0,100.0]), openmc.SurfaceFilter(ybot)]
current_nomatter.estimator = 'analog'
tallies.append(current_nomatter)

currentmesh = openmc.Tally(name='Fdetmesh')
currentmesh.scores = ['current']
currentmesh.filters = [openmc.EnergyFilter([90.0,100.0]), openmc.MeshSurfaceFilter(mesh)]
#currentmesh.estimator = 'analog'
tallies.append(currentmesh)

# %% [markdown]
# ### Settings

# %% [markdown]
# We will now define the settings for the simulation:
#
#
# * What type of simulation we want to run (fixed source or multiplication eigenvalue)
# * How many particles we want to simulate
# * The distribution of the source in space, angle and energy.
#
# Also, we can specify if we want to create a file with all the particles that cross a certain surface

# %% [markdown]
# #### Specify the PATH for the nuclear data and the executable

# %%
openmc_exe= '/home/nacho/openmc/CARLITOS/build/bin/openmc'
openmc_data="/home/nacho/openmc/data/endfb-vii.1-hdf5/cross_sections.xml"

# %%
geom = openmc.Geometry(univ01)
geom.export_to_xml()

mats = openmc.Materials(geom.get_all_materials().values())
mats.cross_sections = openmc_data
mats.export_to_xml()

plots.export_to_xml()

tallies.export_to_xml()
# Out:
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=16.
#   warn(msg, IDWarning)

# %% [markdown]
# #### Plot the geometry

# %%
openmc.plot_geometry(openmc_exec=openmc_exe)
# Out:
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:37:53
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#
#  =======================>     PLOTTING SUMMARY     <========================
#
# Plot ID: 1
# Plot file: plot_1.ppm
# Universe depth: -1
# Plot Type: Slice
# Origin: 0 0 0
# Width:   40   40
# Coloring: Materials
# Basis: XZ
# Pixels: 100 100
#
#  Processing plot 1: plot_1.ppm...

# %% [markdown]
# ### SETINGS

# %% [markdown]
# The input for OpenMC is described by, at least, 3 XML files:
#
# *   `materials.xml`: describes the materials of the system.
# *   `geometry.xml`: describes the geometry of the system.
# *   `settings.xml`: describes the running parameters of the system.
# *   `plots.xml`: describes the plot running parameters.
# *   `tallies.xml`: describes the tallies that will be computing during the simulation.
#
# The OpenMC Python API allows us to create those files and also to postprocess the output.
#
# We should call, for every macro-variable, the `.export_to_xml()` function

# %%
settings = openmc.Settings()
settings.run_mode='fixed source'
settings.particles = int(1e6)
settings.batches = 1
settings.inactive = 0
settings.survival_biasing=True
settings.photon_transport=False

# %% [markdown]
# ### CHAR-0

# %%
source = openmc.Source()
source.space = openmc.stats.Point(xyz=[0, 0, 0])
source.angle = openmc.stats.Isotropic()


energies = np.linspace(589.55, 99500.45, 100)

for i in energies:
    source.energy = openmc.stats.Discrete([i], [1.0])
    settings.source = source
    settings.export_to_xml()
    os.system("rm summary.h5")
    openmc.run(openmc_exec=openmc_exe)
    string1 = 'statepoint.'+str(settings.batches)+'.h5'
    string2 = 'statepoint.'+str(i)+'.h5'
    mv_cmd = 'mv ' + string1 + ' ' + string2 
    os.system(mv_cmd)
# Out:
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:38:04
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Creating state point statepoint.1.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.6006e-02 seconds
#    Reading cross sections          = 4.1162e-03 seconds
#  Total time in simulation          = 2.9820e-01 seconds
#    Time in transport only          = 2.6580e-01 seconds
#    Time in active batches          = 2.9820e-01 seconds
#    Time accumulating tallies       = 2.9493e-02 seconds
#    Time writing statepoints        = 2.8954e-03 seconds
#  Total time for finalization       = 1.8983e-04 seconds
#  Total time elapsed                = 3.3464e-01 seconds
#  Calculation Rate (active)         = 3.35348e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000
#
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:38:05
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Creating state point statepoint.1.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.2367e-02 seconds
#    Reading cross sections          = 3.9363e-03 seconds
#  Total time in simulation          = 2.6829e-01 seconds
#    Time in transport only          = 2.6381e-01 seconds
#    Time in active batches          = 2.6829e-01 seconds
#    Time accumulating tallies       = 1.4802e-03 seconds
#    Time writing statepoints        = 2.9925e-03 seconds
#  Total time for finalization       = 1.2050e-04 seconds
#  Total time elapsed                = 2.8097e-01 seconds
#  Calculation Rate (active)         = 3.72731e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000
#
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:38:05
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Creating state point statepoint.1.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.1728e-02 seconds
#    Reading cross sections          = 3.1680e-03 seconds
#  Total time in simulation          = 2.6518e-01 seconds
#    Time in transport only          = 2.4783e-01 seconds
#    Time in active batches          = 2.6518e-01 seconds
#    Time accumulating tallies       = 1.2381e-02 seconds
#    Time writing statepoints        = 4.9705e-03 seconds
#  Total time for finalization       = 1.2978e-04 seconds
#  Total time elapsed                = 2.7732e-01 seconds
#  Calculation Rate (active)         = 3.77097e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000
#
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:38:05
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Creating state point statepoint.1.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.9918e-02 seconds
#    Reading cross sections          = 3.6763e-03 seconds
#  Total time in simulation          = 2.5493e-01 seconds
#    Time in transport only          = 2.4531e-01 seconds
#    Time in active batches          = 2.5493e-01 seconds
#    Time accumulating tallies       = 5.9841e-03 seconds
#    Time writing statepoints        = 3.6350e-03 seconds
#  Total time for finalization       = 1.4102e-04 seconds
#  Total time elapsed                = 2.9512e-01 seconds
#  Calculation Rate (active)         = 3.92259e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000
#
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:38:05
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Creating state point statepoint.1.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.1545e-02 seconds
#    Reading cross sections          = 3.2893e-03 seconds
#  Total time in simulation          = 2.6325e-01 seconds
#    Time in transport only          = 2.4862e-01 seconds
#    Time in active batches          = 2.6325e-01 seconds
#    Time accumulating tallies       = 1.1591e-02 seconds
#    Time writing statepoints        = 3.0304e-03 seconds
#  Total time for finalization       = 1.1733e-04 seconds
#  Total time elapsed                = 2.7518e-01 seconds
#  Calculation Rate (active)         = 3.79871e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000
#
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:38:06
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Creating state point statepoint.1.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.1949e-02 seconds
#    Reading cross sections          = 3.6870e-03 seconds
#  Total time in simulation          = 2.7903e-01 seconds
#    Time in transport only          = 2.4962e-01 seconds
#    Time in active batches          = 2.7903e-01 seconds
#    Time accumulating tallies       = 2.5422e-02 seconds
#    Time writing statepoints        = 3.9733e-03 seconds
#  Total time for finalization       = 2.1069e-04 seconds
#  Total time elapsed                = 2.9143e-01 seconds
#  Calculation Rate (active)         = 3.58391e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000
#
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:38:06
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Creating state point statepoint.1.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.2075e-02 seconds
#    Reading cross sections          = 3.6234e-03 seconds
#  Total time in simulation          = 2.5220e-01 seconds
#    Time in transport only          = 2.4500e-01 seconds
#    Time in active batches          = 2.5220e-01 seconds
#    Time accumulating tallies       = 1.9717e-03 seconds
#    Time writing statepoints        = 5.2195e-03 seconds
#  Total time for finalization       = 1.4672e-04 seconds
#  Total time elapsed                = 2.6476e-01 seconds
#  Calculation Rate (active)         = 3.96517e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000
#
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:38:06
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Creating state point statepoint.1.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.3888e-02 seconds
#    Reading cross sections          = 3.3224e-03 seconds
#  Total time in simulation          = 2.8185e-01 seconds
#    Time in transport only          = 2.6861e-01 seconds
#    Time in active batches          = 2.8185e-01 seconds
#    Time accumulating tallies       = 9.7147e-03 seconds
#    Time writing statepoints        = 3.5225e-03 seconds
#  Total time for finalization       = 1.3407e-04 seconds
#  Total time elapsed                = 2.9613e-01 seconds
#  Calculation Rate (active)         = 3.54796e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000
#
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:38:07
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Creating state point statepoint.1.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.1240e-02 seconds
#    Reading cross sections          = 3.4285e-03 seconds
#  Total time in simulation          = 2.7691e-01 seconds
#    Time in transport only          = 2.7173e-01 seconds
#    Time in active batches          = 2.7691e-01 seconds
#    Time accumulating tallies       = 1.7113e-03 seconds
#    Time writing statepoints        = 3.4590e-03 seconds
#  Total time for finalization       = 1.3422e-04 seconds
#  Total time elapsed                = 2.8853e-01 seconds
#  Calculation Rate (active)         = 3.61128e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000
#
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:38:07
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Creating state point statepoint.1.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.1262e-02 seconds
#    Reading cross sections          = 2.9117e-03 seconds
#  Total time in simulation          = 2.8393e-01 seconds
#    Time in transport only          = 2.7800e-01 seconds
#    Time in active batches          = 2.8393e-01 seconds
#    Time accumulating tallies       = 2.1077e-03 seconds
#    Time writing statepoints        = 3.8163e-03 seconds
#  Total time for finalization       = 2.1837e-04 seconds
#  Total time elapsed                = 2.9566e-01 seconds
#  Calculation Rate (active)         = 3.52198e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000
#
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:38:07
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Creating state point statepoint.1.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.1889e-02 seconds
#    Reading cross sections          = 3.7471e-03 seconds
#  Total time in simulation          = 2.9293e-01 seconds
#    Time in transport only          = 2.6894e-01 seconds
#    Time in active batches          = 2.9293e-01 seconds
#    Time accumulating tallies       = 2.0821e-02 seconds
#    Time writing statepoints        = 3.1674e-03 seconds
#  Total time for finalization       = 1.3851e-04 seconds
#  Total time elapsed                = 3.0517e-01 seconds
#  Calculation Rate (active)         = 3.41376e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000
#
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:38:08
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Creating state point statepoint.1.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.4712e-02 seconds
#    Reading cross sections          = 3.9972e-03 seconds
#  Total time in simulation          = 2.7990e-01 seconds
#    Time in transport only          = 2.7196e-01 seconds
#    Time in active batches          = 2.7990e-01 seconds
#    Time accumulating tallies       = 3.6406e-03 seconds
#    Time writing statepoints        = 4.2886e-03 seconds
#  Total time for finalization       = 1.5538e-04 seconds
#  Total time elapsed                = 2.9501e-01 seconds
#  Calculation Rate (active)         = 3.57275e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000
#
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:38:08
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Creating state point statepoint.1.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 2.3278e-02 seconds
#    Reading cross sections          = 3.9673e-03 seconds
#  Total time in simulation          = 2.6300e-01 seconds
#    Time in transport only          = 2.5795e-01 seconds
#    Time in active batches          = 2.6300e-01 seconds
#    Time accumulating tallies       = 6.0621e-04 seconds
#    Time writing statepoints        = 4.4436e-03 seconds
#  Total time for finalization       = 2.8199e-04 seconds
#  Total time elapsed                = 2.8681e-01 seconds
#  Calculation Rate (active)         = 3.80222e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000
#
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:38:08
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Creating state point statepoint.1.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.1531e-02 seconds
#    Reading cross sections          = 3.6985e-03 seconds
#  Total time in simulation          = 3.3579e-01 seconds
#    Time in transport only          = 2.9879e-01 seconds
#    Time in active batches          = 3.3579e-01 seconds
#    Time accumulating tallies       = 3.2433e-02 seconds
#    Time writing statepoints        = 4.5671e-03 seconds
#  Total time for finalization       = 1.6309e-04 seconds
#  Total time elapsed                = 3.4772e-01 seconds
#  Calculation Rate (active)         = 2.97806e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000
#
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:38:09
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Creating state point statepoint.1.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 2.4616e-02 seconds
#    Reading cross sections          = 3.9064e-03 seconds
#  Total time in simulation          = 3.2556e-01 seconds
#    Time in transport only          = 2.7621e-01 seconds
#    Time in active batches          = 3.2556e-01 seconds
#    Time accumulating tallies       = 4.5622e-02 seconds
#    Time writing statepoints        = 3.7198e-03 seconds
#  Total time for finalization       = 2.6248e-04 seconds
#  Total time elapsed                = 3.5059e-01 seconds
#  Calculation Rate (active)         = 3.07166e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000
#
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
# ...
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000
#
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:38:32
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Creating state point statepoint.1.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.0217e-02 seconds
#    Reading cross sections          = 3.0465e-03 seconds
#  Total time in simulation          = 2.4081e-01 seconds
#    Time in transport only          = 2.3696e-01 seconds
#    Time in active batches          = 2.4081e-01 seconds
#    Time accumulating tallies       = 1.2659e-04 seconds
#    Time writing statepoints        = 3.7170e-03 seconds
#  Total time for finalization       = 1.1443e-04 seconds
#  Total time elapsed                = 2.5134e-01 seconds
#  Calculation Rate (active)         = 4.15272e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000
#
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:38:32
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Creating state point statepoint.1.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 9.9933e-03 seconds
#    Reading cross sections          = 3.1687e-03 seconds
#  Total time in simulation          = 2.6116e-01 seconds
#    Time in transport only          = 2.5210e-01 seconds
#    Time in active batches          = 2.6116e-01 seconds
#    Time accumulating tallies       = 5.1856e-03 seconds
#    Time writing statepoints        = 3.8768e-03 seconds
#  Total time for finalization       = 1.2465e-04 seconds
#  Total time elapsed                = 2.7148e-01 seconds
#  Calculation Rate (active)         = 3.82902e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000
#
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:38:32
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Creating state point statepoint.1.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 9.3384e-03 seconds
#    Reading cross sections          = 2.8224e-03 seconds
#  Total time in simulation          = 2.8513e-01 seconds
#    Time in transport only          = 2.7987e-01 seconds
#    Time in active batches          = 2.8513e-01 seconds
#    Time accumulating tallies       = 1.8548e-03 seconds
#    Time writing statepoints        = 3.3978e-03 seconds
#  Total time for finalization       = 1.1660e-04 seconds
#  Total time elapsed                = 2.9477e-01 seconds
#  Calculation Rate (active)         = 3.50722e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000
#
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:38:33
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Creating state point statepoint.1.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 9.3845e-03 seconds
#    Reading cross sections          = 2.8082e-03 seconds
#  Total time in simulation          = 2.6420e-01 seconds
#    Time in transport only          = 2.6013e-01 seconds
#    Time in active batches          = 2.6420e-01 seconds
#    Time accumulating tallies       = 8.7508e-04 seconds
#    Time writing statepoints        = 3.1930e-03 seconds
#  Total time for finalization       = 1.3212e-04 seconds
#  Total time elapsed                = 2.7390e-01 seconds
#  Calculation Rate (active)         = 3.78501e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000
#
# CORRIOOOOO
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-04 11:38:33
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#
#  ===============>     FIXED SOURCE TRANSPORT SIMULATION     <===============
#
#  Simulating batch 1
#  Creating state point statepoint.1.h5...
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 9.6212e-03 seconds
#    Reading cross sections          = 2.7183e-03 seconds
#  Total time in simulation          = 2.4583e-01 seconds
#    Time in transport only          = 2.4232e-01 seconds
#    Time in active batches          = 2.4583e-01 seconds
#    Time accumulating tallies       = 9.1920e-06 seconds
#    Time writing statepoints        = 3.5039e-03 seconds
#  Total time for finalization       = 1.2468e-04 seconds
#  Total time elapsed                = 2.5578e-01 seconds
#  Calculation Rate (active)         = 4.06781e+06 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = 1.00000

# %% [markdown]
# ### Reading the tallies

# %% [markdown]
# The run creates a binary file called *Statepoint*. We will load this file, extract the tallies and plot them.

# %%
sp = {}
talli = {}
tallimesh = {}
fadj = np.zeros(len(energies), dtype=float)
fadjerr = np.zeros(len(energies), dtype=float)
fadjmesh = np.zeros(len(energies), dtype=float)

for i in range(len(energies)):
    string3 = 'statepoint.'+str(energies[i])+'.h5'
    sp[i]=openmc.StatePoint(string3)
    talli[i]=sp[i].get_tally(name='Fdet')
    fadj[i]=(-1.0)*float(talli[i].mean.flatten())
    fadjerr[i]=float(talli[i].std_dev.flatten())

    tallimesh[i]=sp[i].get_tally(name='Fdetmesh').get_pandas_dataframe()
    if len(tallimesh[i].columns)>9:
        tallimesh[i].columns = ['Emin', 'Emax', 'x', 'y', 'z', 'surf', 'nuclide', 'score', 'mean', 'std_dev']    
    else:
        tallimesh[i].columns = ['Emin', 'Emax', 'x', 'y', 'z', 'surf', 'nuclide', 'score', 'mean']
    fadjmesh[i]=tallimesh[i][tallimesh[i]['surf']=='y-min out']['mean'].values[0]

plt.plot(energies, fadj)
plt.plot(energies, fadjmesh)
np.savetxt('results.txt', np.column_stack((energies, fadj)), delimiter='\t')
# Out:
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
