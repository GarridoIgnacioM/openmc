# %% [markdown]
# # `OpenMC` example

# %% [markdown]
# ### Importing the Python modules necessary to run OpenMC

# %%
import os
os.environ['OPENMC_CROSS_SECTIONS'] = '/home/nacho/openmc/data/endfb-vii.1-hdf5/cross_sections.xml'
import numpy as np
import matplotlib.pyplot as plt
import openmc
import pandas as pd
from matplotlib.colors import LogNorm
from PIL import Image   
from uncertainties import ufloat, unumpy
import h5py

# %% [markdown]
# ### Materials

# %% [markdown]
# Materials are defined by calling [`openmc.Material()`](https://docs.openmc.org/en/stable/pythonapi/generated/openmc.Material.html#openmc-material) to create the material object and then using the `mat.add_nuclide()` or `mat.add_element()` methods to build the composition.
#
# The first parameter is the nuclide or element, the second one is the fraction, and the third one is the units.
#
# Compositions can be expressed in percentage of atoms (`ao`), percentage of mass (`wo`) or atom density (`at/cm3`).
#
# To se the total density of the material, the module `.set_density()` should be called. The possible units are `g/cm3`, `atom/b-cm`, `kg/m3` or `sum` (asumes that the concentrations of the nuclides/elements are in `atom/b-cm`)
#
# It is possible to ad an $S(\alpha,\beta)$ library, which will replace the cross sections for low energies.

# %%
deu = openmc.Material(1, 'deuterio', 293.5943174)
deu.add_nuclide('H2', 1, 'ao')
deu.set_density('atom/cm3', (985796446e13/0.0165)*0.01)
print(deu)



hid = openmc.Material(2, 'hidrogeno', 293.5943174)
hid.add_nuclide('H1', 1, 'ao')
hid.set_density('g/cm3', 0.01)
print(hid)
# Out:
# Material
# 	ID             =	1
# 	Name           =	deuterio
# 	Temperature    =	293.5943174
# 	Density        =	5.974523915151516e+21 [atom/cm3]
# 	Volume         =	None [cm^3]
# 	S(a,b) Tables
# 	Nuclides
# 	H2             =	1            [ao]
#
# Material
# 	ID             =	2
# 	Name           =	hidrogeno
# 	Temperature    =	293.5943174
# 	Density        =	0.01 [g/cm3]
# 	Volume         =	None [cm^3]
# 	S(a,b) Tables
# 	Nuclides
# 	H1             =	1            [ao]
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=1.
#   warn(msg, IDWarning)
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another Material instance already exists with id=2.
#   warn(msg, IDWarning)

# %% [markdown]
# ### Geometry

# %% [markdown]
# The geometry is defined using [Constructive Solid Geometry](https://en.wikipedia.org/wiki/Constructive_solid_geometry) (CSG). First, a set of simple surfaces are defined. Mathematically, the surfaces are defined as $f(x,y,z)=0$, giving the parameters of the function. Each surface defines two regions, one where $f(x,y,z)>0$, and one where $f(x,y,z)<0$. By combining the regions using the union (`|`), intersection (`&`) and complement (`~`) we can define regions of the space.
#
# The basic unit of the geometry in OpenMC is the *Cell*, which is a region of space with something that fills it.
#
# The surfaces with `vacuum` boundary conditions means that the particles that reach this surface will be eliminated. By default, the `transmission` boundary is setted. Other options are `reflective`, `periodic` and `white`.
#
# A collection of cells is a *Universe*, and it can be used to fill other cells for nested geometries.
#
# The surface units are in `cm`

# %% [markdown]
# #### Surfaces

# %%
L=20
xtop=openmc.XPlane(x0=L/2, boundary_type='vacuum', surface_id=1)
xbot=openmc.XPlane(x0=-L/2, boundary_type='vacuum', surface_id=2)
ytop=openmc.YPlane(y0=L/2, boundary_type='vacuum', surface_id=3)
ybot=openmc.YPlane(y0=-L/2, boundary_type='vacuum', surface_id=4)
ztop=openmc.ZPlane(z0=L/2, boundary_type='vacuum', surface_id=5)
zbot=openmc.ZPlane(z0=-L/2, boundary_type='vacuum', surface_id=6)
# Out:
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=1.
#   warn(msg, IDWarning)
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=2.
#   warn(msg, IDWarning)
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=3.
#   warn(msg, IDWarning)
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=4.
#   warn(msg, IDWarning)
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=5.
#   warn(msg, IDWarning)
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another Surface instance already exists with id=6.
#   warn(msg, IDWarning)

# %% [markdown]
# #### Regions

# %%
region=-xtop & +xbot & -ytop & +ybot & -ztop & +zbot

# %% [markdown]
# #### Cells

# %%
cell=openmc.Cell(region=region,fill=deu,cell_id=1)
# Out:
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another Cell instance already exists with id=1.
#   warn(msg, IDWarning)

# %% [markdown]
# #### Universe(s)

# %%
univ01 =openmc.Universe(cells= [cell], universe_id=1)
# Out:
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another UniverseBase instance already exists with id=1.
#   warn(msg, IDWarning)

# %% [markdown]
# The `Universe()` class has a `plot()` method to show the geometry. L We can plot the geometry using different colors for the different materials or for the different cells

# %%
univ01.plot(width=(40, 40),  basis='xy', color_by='material')
univ01.plot(width=(40, 40), basis='xz', color_by='material')
univ01.plot(width=(40, 40), basis='yz', color_by='material')

# %% [markdown]
# ### Plots (optional)

# %% [markdown]
# It is possible to call a `openmc.plot` run command later. In this case, the `Plot` module should be called and defined

# %%
plots = openmc.Plots()

plot_xz = openmc.Plot()
plot_xz.id = 1
plot_xz.basis = 'xz'
plot_xz.origin = (0,0,0.0)
plot_xz.width = (40,40)
plot_xz.pixels = (100, 100)
plot_xz.color_by='material'
plots.append(plot_xz)
# Out:
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another PlotBase instance already exists with id=1.
#   warn(msg, IDWarning)

# %% [markdown]
# ### mesh

# %%
mesh = openmc.RegularMesh(mesh_id=1)
mesh.lower_left=(-L/2,-L/2,-L/2)
mesh.upper_right=(L/2,L/2,L/2)
mesh.dimension = [1, 1, 1]
# Out:
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another MeshBase instance already exists with id=1.
#   warn(msg, IDWarning)

# %% [markdown]
# ### Tallies (optional)

# %% [markdown]
# With the `Tallies` module, we can define what we want to compute from the simulations. These tallies count a specific *Score* discrimined by different *Filters*.

# %% [markdown]
# #### Filters

# %%
tallies = openmc.Tallies()
current_nomatter = openmc.Tally(name='Fdet')
current_nomatter.scores = ['current']
current_nomatter.filters = [openmc.EnergyFilter([90.0,100.0]), openmc.SurfaceFilter(ybot)]
current_nomatter.estimator = 'analog'
tallies.append(current_nomatter)

currentmesh = openmc.Tally(name='Fdetmesh')
currentmesh.scores = ['current']
currentmesh.filters = [openmc.EnergyFilter([90.0,100.0]), openmc.MeshSurfaceFilter(mesh)]
#currentmesh.estimator = 'analog'
tallies.append(currentmesh)

# %% [markdown]
# ### Settings

# %% [markdown]
# We will now define the settings for the simulation:
#
#
# * What type of simulation we want to run (fixed source or multiplication eigenvalue)
# * How many particles we want to simulate
# * The distribution of the source in space, angle and energy.
#
# Also, we can specify if we want to create a file with all the particles that cross a certain surface

# %% [markdown]
# #### Specify the PATH for the nuclear data and the executable

# %%
openmc_exe= '/home/nacho/openmc/CARLITOS/build/bin/openmc'
openmc_data="/home/nacho/openmc/data/endfb-vii.1-hdf5/cross_sections.xml"

# %%
geom = openmc.Geometry(univ01)
geom.export_to_xml()

mats = openmc.Materials(geom.get_all_materials().values())
mats.cross_sections = openmc_data
mats.export_to_xml()

plots.export_to_xml()

tallies.export_to_xml()
# Out:
# /home/nacho/.local/lib/python3.10/site-packages/openmc/mixin.py:70: IDWarning: Another Filter instance already exists with id=9.
#   warn(msg, IDWarning)

# %% [markdown]
# #### Plot the geometry

# %%
openmc.plot_geometry(openmc_exec=openmc_exe)
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 17:28:16
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#
#  =======================>     PLOTTING SUMMARY     <========================
#
# Plot ID: 1
# Plot file: plot_1.png
# Universe depth: -1
# Plot Type: Slice
# Origin: 0 0 0
# Width:   40   40
# Coloring: Materials
# Basis: XZ
# Pixels: 100 100
#
#  Processing plot 1: plot_1.png...

# %% [markdown]
# ### SETINGS

# %% [markdown]
# The input for OpenMC is described by, at least, 3 XML files:
#
# *   `materials.xml`: describes the materials of the system.
# *   `geometry.xml`: describes the geometry of the system.
# *   `settings.xml`: describes the running parameters of the system.
# *   `plots.xml`: describes the plot running parameters.
# *   `tallies.xml`: describes the tallies that will be computing during the simulation.
#
# The OpenMC Python API allows us to create those files and also to postprocess the output.
#
# We should call, for every macro-variable, the `.export_to_xml()` function

# %%
settings = openmc.Settings()
settings.run_mode='CHAR-0'
settings.particles = int(1e6)
settings.batches = 1
settings.inactive = 0
settings.survival_biasing=True
settings.photon_transport=False

# %% [markdown]
# ### CHAR-0

# %%
source = openmc.Source()
source.space = openmc.stats.Point(xyz=[0, 0, 0])
source.angle = openmc.stats.Isotropic()


energies = np.linspace(589.55, 99500.45, 100)

for i in energies:
    source.energy = openmc.stats.Discrete([i], [1.0])
    settings.source = source
    settings.export_to_xml()
    os.system("rm summary.h5")
    openmc.run(openmc_exec=openmc_exe)
    string1 = 'statepoint.'+str(settings.batches)+'.h5'
    string2 = 'statepoint.'+str(i)+'.h5'
    mv_cmd = 'mv ' + string1 + ' ' + string2 
    os.system(mv_cmd)
# Out:
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 18:11:38
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#  Simulating batch 1
# PRINTEO DE PRUEBA A1
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 3.1861e-02 seconds
#    Reading cross sections          = 3.6173e-03 seconds
#  Total time in simulation          = 3.1129e-02 seconds
#    Time in transport only          = 9.8782e-03 seconds
#    Time in active batches          = 3.1129e-02 seconds
#    Time accumulating tallies       = 2.1246e-02 seconds
#    Time writing statepoints        = 0.0000e+00 seconds
#  Total time for finalization       = 2.6680e-04 seconds
#  Total time elapsed                = 6.3467e-02 seconds
#  Calculation Rate (active)         = -32.1246 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 18:11:38
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#  Simulating batch 1
# PRINTEO DE PRUEBA A1
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.4372e-02 seconds
#    Reading cross sections          = 2.6894e-03 seconds
#  Total time in simulation          = 3.2050e-05 seconds
#    Time in transport only          = 2.6017e-05 seconds
#    Time in active batches          = 3.2050e-05 seconds
#    Time accumulating tallies       = 3.4430e-06 seconds
#    Time writing statepoints        = 0.0000e+00 seconds
#  Total time for finalization       = 1.9954e-04 seconds
#  Total time elapsed                = 1.4805e-02 seconds
#  Calculation Rate (active)         = -31201.2 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 18:11:38
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#  Simulating batch 1
# PRINTEO DE PRUEBA A1
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.1886e-02 seconds
#    Reading cross sections          = 3.0019e-03 seconds
#  Total time in simulation          = 2.7076e-04 seconds
#    Time in transport only          = 2.6332e-04 seconds
#    Time in active batches          = 2.7076e-04 seconds
#    Time accumulating tallies       = 3.9700e-06 seconds
#    Time writing statepoints        = 0.0000e+00 seconds
#  Total time for finalization       = 2.3825e-04 seconds
#  Total time elapsed                = 1.2611e-02 seconds
#  Calculation Rate (active)         = -3693.31 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 18:11:38
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#  Simulating batch 1
# PRINTEO DE PRUEBA A1
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 2.9110e-02 seconds
#    Reading cross sections          = 3.0629e-03 seconds
#  Total time in simulation          = 5.9532e-03 seconds
#    Time in transport only          = 5.9453e-03 seconds
#    Time in active batches          = 5.9532e-03 seconds
#    Time accumulating tallies       = 4.6100e-06 seconds
#    Time writing statepoints        = 0.0000e+00 seconds
#  Total time for finalization       = 2.4797e-04 seconds
#  Total time elapsed                = 3.5539e-02 seconds
#  Calculation Rate (active)         = -167.976 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 18:11:38
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#  Simulating batch 1
# PRINTEO DE PRUEBA A1
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.2192e-02 seconds
#    Reading cross sections          = 2.8500e-03 seconds
#  Total time in simulation          = 9.9750e-06 seconds
#    Time in transport only          = 4.2620e-06 seconds
#    Time in active batches          = 9.9750e-06 seconds
#    Time accumulating tallies       = 3.6190e-06 seconds
#    Time writing statepoints        = 0.0000e+00 seconds
#  Total time for finalization       = 1.9953e-04 seconds
#  Total time elapsed                = 1.2612e-02 seconds
#  Calculation Rate (active)         = -100251 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 18:11:38
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
# mv: cannot stat 'statepoint.1.h5': No such file or directory
# mv: cannot stat 'statepoint.1.h5': No such file or directory
# mv: cannot stat 'statepoint.1.h5': No such file or directory
# mv: cannot stat 'statepoint.1.h5': No such file or directory
# mv: cannot stat 'statepoint.1.h5': No such file or directory
# mv: cannot stat 'statepoint.1.h5': No such file or directory
#  Maximum neutron transport energy: 150000000 eV for H2
#  Simulating batch 1
# PRINTEO DE PRUEBA A1
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.2820e-02 seconds
#    Reading cross sections          = 3.0393e-03 seconds
#  Total time in simulation          = 7.0501e-05 seconds
#    Time in transport only          = 6.4211e-05 seconds
#    Time in active batches          = 7.0501e-05 seconds
#    Time accumulating tallies       = 4.0130e-06 seconds
#    Time writing statepoints        = 0.0000e+00 seconds
#  Total time for finalization       = 2.1818e-04 seconds
#  Total time elapsed                = 1.3355e-02 seconds
#  Calculation Rate (active)         = -14184.2 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 18:11:38
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#  Simulating batch 1
# PRINTEO DE PRUEBA A1
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 2.8307e-02 seconds
#    Reading cross sections          = 3.4854e-03 seconds
#  Total time in simulation          = 4.7023e-02 seconds
#    Time in transport only          = 7.7873e-03 seconds
#    Time in active batches          = 4.7023e-02 seconds
#    Time accumulating tallies       = 3.9230e-02 seconds
#    Time writing statepoints        = 0.0000e+00 seconds
#  Total time for finalization       = 1.7794e-03 seconds
#  Total time elapsed                = 7.7312e-02 seconds
#  Calculation Rate (active)         = -21.2662 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 18:11:38
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#  Simulating batch 1
# PRINTEO DE PRUEBA A1
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.0977e-02 seconds
#    Reading cross sections          = 3.7850e-03 seconds
#  Total time in simulation          = 1.1905e-05 seconds
#    Time in transport only          = 5.4390e-06 seconds
#    Time in active batches          = 1.1905e-05 seconds
#    Time accumulating tallies       = 4.2660e-06 seconds
#    Time writing statepoints        = 0.0000e+00 seconds
#  Total time for finalization       = 1.2963e-04 seconds
#  Total time elapsed                = 1.1334e-02 seconds
#  Calculation Rate (active)         = -83998.3 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 18:11:38
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#  Simulating batch 1
# PRINTEO DE PRUEBA A1
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.2151e-02 seconds
#    Reading cross sections          = 3.3580e-03 seconds
#  Total time in simulation          = 1.4874e-03 seconds
#    Time in transport only          = 1.4801e-03 seconds
#    Time in active batches          = 1.4874e-03 seconds
#    Time accumulating tallies       = 4.4380e-06 seconds
#    Time writing statepoints        = 0.0000e+00 seconds
#  Total time for finalization       = 1.9870e-04 seconds
#  Total time elapsed                = 1.4018e-02 seconds
#  Calculation Rate (active)         = -672.326 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 18:11:38
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#  Simulating batch 1
# PRINTEO DE PRUEBA A1
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.5038e-02 seconds
#    Reading cross sections          = 2.8949e-03 seconds
#  Total time in simulation          = 1.0010e-05 seconds
#    Time in transport only          = 4.5770e-06 seconds
#    Time in active batches          = 1.0010e-05 seconds
#    Time accumulating tallies       = 3.4280e-06 seconds
#    Time writing statepoints        = 0.0000e+00 seconds
#  Total time for finalization       = 1.9678e-04 seconds
#  Total time elapsed                = 1.5445e-02 seconds
#  Calculation Rate (active)         = -99900.1 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 18:11:38
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#  Simulating batch 1
# PRINTEO DE PRUEBA A1
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.1785e-02 seconds
#    Reading cross sections          = 3.0449e-03 seconds
#  Total time in simulation          = 8.7890e-06 seconds
#    Time in transport only          = 3.5500e-06 seconds
#    Time in active batches          = 8.7890e-06 seconds
#    Time accumulating tallies       = 3.4900e-06 seconds
#    Time writing statepoints        = 0.0000e+00 seconds
#  Total time for finalization       = 1.8135e-04 seconds
#  Total time elapsed                = 1.2143e-02 seconds
#  Calculation Rate (active)         = -113779 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 18:11:38
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
# mv: cannot stat 'statepoint.1.h5': No such file or directory
# mv: cannot stat 'statepoint.1.h5': No such file or directory
# mv: cannot stat 'statepoint.1.h5': No such file or directory
# mv: cannot stat 'statepoint.1.h5': No such file or directory
# mv: cannot stat 'statepoint.1.h5': No such file or directory
# mv: cannot stat 'statepoint.1.h5': No such file or directory
# mv: cannot stat 'statepoint.1.h5': No such file or directory
# mv: cannot stat 'statepoint.1.h5': No such file or directory
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#  Simulating batch 1
# PRINTEO DE PRUEBA A1
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.1985e-02 seconds
#    Reading cross sections          = 2.9858e-03 seconds
#  Total time in simulation          = 8.6260e-06 seconds
#    Time in transport only          = 3.4230e-06 seconds
#    Time in active batches          = 8.6260e-06 seconds
#    Time accumulating tallies       = 3.3160e-06 seconds
#    Time writing statepoints        = 0.0000e+00 seconds
#  Total time for finalization       = 1.8069e-04 seconds
#  Total time elapsed                = 1.2353e-02 seconds
#  Calculation Rate (active)         = -115929 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 18:11:38
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#  Simulating batch 1
# PRINTEO DE PRUEBA A1
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 2.8288e-02 seconds
#    Reading cross sections          = 3.6368e-03 seconds
#  Total time in simulation          = 1.1461e-05 seconds
#    Time in transport only          = 5.6830e-06 seconds
#    Time in active batches          = 1.1461e-05 seconds
#    Time accumulating tallies       = 3.4950e-06 seconds
#    Time writing statepoints        = 0.0000e+00 seconds
#  Total time for finalization       = 1.9163e-04 seconds
#  Total time elapsed                = 2.8694e-02 seconds
#  Calculation Rate (active)         = -87252.4 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 18:11:38
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#  Simulating batch 1
# PRINTEO DE PRUEBA A1
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.2156e-02 seconds
#    Reading cross sections          = 3.0811e-03 seconds
#  Total time in simulation          = 1.0344e-05 seconds
#    Time in transport only          = 4.7380e-06 seconds
#    Time in active batches          = 1.0344e-05 seconds
#    Time accumulating tallies       = 3.3960e-06 seconds
#    Time writing statepoints        = 0.0000e+00 seconds
#  Total time for finalization       = 2.1047e-04 seconds
#  Total time elapsed                = 1.2571e-02 seconds
#  Calculation Rate (active)         = -96674.4 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 18:11:38
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#  Simulating batch 1
# PRINTEO DE PRUEBA A1
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.2857e-02 seconds
#    Reading cross sections          = 3.0436e-03 seconds
#  Total time in simulation          = 9.9720e-06 seconds
#    Time in transport only          = 4.6220e-06 seconds
#    Time in active batches          = 9.9720e-06 seconds
#    Time accumulating tallies       = 3.5520e-06 seconds
#    Time writing statepoints        = 0.0000e+00 seconds
#  Total time for finalization       = 2.0704e-04 seconds
#  Total time elapsed                = 1.3269e-02 seconds
#  Calculation Rate (active)         = -100281 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
# ...
#  Total time for finalization       = 1.3095e-04 seconds
#  Total time elapsed                = 2.7571e-02 seconds
#  Calculation Rate (active)         = -93624.2 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 18:11:41
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#  Simulating batch 1
# PRINTEO DE PRUEBA A1
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.2179e-02 seconds
#    Reading cross sections          = 3.0148e-03 seconds
#  Total time in simulation          = 7.8323e-04 seconds
#    Time in transport only          = 7.7645e-04 seconds
#    Time in active batches          = 7.8323e-04 seconds
#    Time accumulating tallies       = 3.9000e-06 seconds
#    Time writing statepoints        = 0.0000e+00 seconds
#  Total time for finalization       = 2.4737e-04 seconds
#  Total time elapsed                = 1.3404e-02 seconds
#  Calculation Rate (active)         = -1276.77 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 18:11:41
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#  Simulating batch 1
# PRINTEO DE PRUEBA A1
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.4335e-02 seconds
#    Reading cross sections          = 3.2173e-03 seconds
#  Total time in simulation          = 1.2199e-05 seconds
#    Time in transport only          = 6.1310e-06 seconds
#    Time in active batches          = 1.2199e-05 seconds
#    Time accumulating tallies       = 3.4360e-06 seconds
#    Time writing statepoints        = 0.0000e+00 seconds
#  Total time for finalization       = 2.0996e-04 seconds
#  Total time elapsed                = 1.4771e-02 seconds
#  Calculation Rate (active)         = -81973.9 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 18:11:41
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#  Simulating batch 1
# PRINTEO DE PRUEBA A1
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.1916e-02 seconds
#    Reading cross sections          = 3.0384e-03 seconds
#  Total time in simulation          = 1.1327e-05 seconds
#    Time in transport only          = 5.1690e-06 seconds
#    Time in active batches          = 1.1327e-05 seconds
#    Time accumulating tallies       = 3.6920e-06 seconds
#    Time writing statepoints        = 0.0000e+00 seconds
#  Total time for finalization       = 2.2397e-04 seconds
#  Total time elapsed                = 1.2364e-02 seconds
#  Calculation Rate (active)         = -88284.6 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 18:11:41
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#  Simulating batch 1
# PRINTEO DE PRUEBA A1
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 1.3445e-02 seconds
#    Reading cross sections          = 2.9975e-03 seconds
#  Total time in simulation          = 2.5720e-03 seconds
#    Time in transport only          = 1.8334e-03 seconds
#    Time in active batches          = 2.5720e-03 seconds
#    Time accumulating tallies       = 7.3481e-04 seconds
#    Time writing statepoints        = 0.0000e+00 seconds
#  Total time for finalization       = 2.5951e-04 seconds
#  Total time elapsed                = 1.6487e-02 seconds
#  Calculation Rate (active)         = -388.809 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
#                                 %%%%%%%%%%%%%%%
#                            %%%%%%%%%%%%%%%%%%%%%%%%
#                         %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                       %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                     %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                    %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#                                     %%%%%%%%%%%%%%%%%%%%%%%%
#                                      %%%%%%%%%%%%%%%%%%%%%%%%
#                  ###############      %%%%%%%%%%%%%%%%%%%%%%%%
#                 ##################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ###################     %%%%%%%%%%%%%%%%%%%%%%%
#                 ####################     %%%%%%%%%%%%%%%%%%%%%%
#                 #####################     %%%%%%%%%%%%%%%%%%%%%
#                 ######################     %%%%%%%%%%%%%%%%%%%%
#                 #######################     %%%%%%%%%%%%%%%%%%
#                  #######################     %%%%%%%%%%%%%%%%%
#                  ######################     %%%%%%%%%%%%%%%%%
#                   ####################     %%%%%%%%%%%%%%%%%
#                     #################     %%%%%%%%%%%%%%%%%
#                      ###############     %%%%%%%%%%%%%%%%
#                        ############     %%%%%%%%%%%%%%%
#                           ########     %%%%%%%%%%%%%%
#                                       %%%%%%%%%%%
#
#                  | The OpenMC Monte Carlo Code
#        Copyright | 2011-2023 MIT, UChicago Argonne LLC, and contributors
#          License | https://docs.openmc.org/en/latest/license.html
#          Version | 0.13.4-dev
#         Git SHA1 | 8fbe14760931d95721c05d107ce6e910b8113adc
#        Date/Time | 2023-05-08 18:11:41
#   OpenMP Threads | 12
#
#  Reading settings XML file...
#  Reading cross sections XML file...
#  Reading materials XML file...
#  Reading geometry XML file...
#  Reading H2 from /home/nacho/openmc/data/endfb-vii.1-hdf5/neutron/H2.h5
#  Minimum neutron data temperature: 294 K
#  Maximum neutron data temperature: 294 K
#  Reading tallies XML file...
#  Preparing distributed cell instances...
#  Reading plot XML file...
#  Writing summary.h5 file...
#  Maximum neutron transport energy: 150000000 eV for H2
#  Simulating batch 1
# PRINTEO DE PRUEBA A1
#
#  =======================>     TIMING STATISTICS     <=======================
#
#  Total time for initialization     = 2.0463e-02 seconds
#    Reading cross sections          = 4.7216e-03 seconds
#  Total time in simulation          = 8.7590e-04 seconds
#    Time in transport only          = 8.6620e-04 seconds
#    Time in active batches          = 8.7590e-04 seconds
#    Time accumulating tallies       = 6.0390e-06 seconds
#    Time writing statepoints        = 0.0000e+00 seconds
#  Total time for finalization       = 2.3757e-04 seconds
#  Total time elapsed                = 2.1796e-02 seconds
#  Calculation Rate (active)         = -1141.69 particles/second
#
#  ============================>     RESULTS     <============================
#
#  WARNING: Could not compute uncertainties -- only one active batch simulated!
#  Leakage Fraction           = -nan
#
# The run mode at the end of the simulation is: 6
# mv: cannot stat 'statepoint.1.h5': No such file or directory
# mv: cannot stat 'statepoint.1.h5': No such file or directory

# %% [markdown]
# ### Reading the tallies

# %% [markdown]
# The run creates a binary file called *Statepoint*. We will load this file, extract the tallies and plot them.

# %%
sp = {}
talli = {}
tallimesh = {}
fadj = np.zeros(len(energies), dtype=float)
fadjerr = np.zeros(len(energies), dtype=float)
fadjmesh = np.zeros(len(energies), dtype=float)

for i in range(len(energies)):
    string3 = 'statepoint.'+str(energies[i])+'.h5'
    sp[i]=openmc.StatePoint(string3)
    talli[i]=sp[i].get_tally(name='Fdet')
    fadj[i]=(-1.0)*float(talli[i].mean.flatten())
    fadjerr[i]=float(talli[i].std_dev.flatten())

    tallimesh[i]=sp[i].get_tally(name='Fdetmesh').get_pandas_dataframe()
    if len(tallimesh[i].columns)>9:
        tallimesh[i].columns = ['Emin', 'Emax', 'x', 'y', 'z', 'surf', 'nuclide', 'score', 'mean', 'std_dev']    
    else:
        tallimesh[i].columns = ['Emin', 'Emax', 'x', 'y', 'z', 'surf', 'nuclide', 'score', 'mean']
    fadjmesh[i]=tallimesh[i][tallimesh[i]['surf']=='y-min out']['mean'].values[0]

plt.plot(energies, fadj)
plt.plot(energies, fadjmesh)
np.savetxt('results.txt', np.column_stack((energies, fadj)), delimiter='\t')
# Out:
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
# /home/nacho/.local/lib/python3.10/site-packages/openmc/tallies.py:279: RuntimeWarning: invalid value encountered in divide
#   self._std_dev[nonzero] = np.sqrt((self.sum_sq[nonzero]/n -
